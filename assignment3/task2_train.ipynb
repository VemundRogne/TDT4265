# %% [markdown]
# This is a simple example on how you can use a jupyter notebook to train your model :)

# %%
import torch
import torch.nn as nn
from dataloaders import load_cifar10
from trainer import Trainer, compute_loss_and_accuracy
from task2 import create_plots

# %%
import task2

epochs = 100
batch_size = 64
learning_rate = 5e-2 #5e-2 # Should be 5e-5 for LeNet
early_stop_count = 4
dataloaders = load_cifar10(batch_size)
model = task2.ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model,
    dataloaders
)
trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2048, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 50.02, Global step:    351, Validation Loss: 1.41, Validation Accuracy: 0.492
# Epoch: 0, Batches per seconds: 54.19, Global step:    702, Validation Loss: 1.14, Validation Accuracy: 0.592
# Epoch: 1, Batches per seconds: 52.87, Global step:   1053, Validation Loss: 1.01, Validation Accuracy: 0.640
# Epoch: 1, Batches per seconds: 54.68, Global step:   1404, Validation Loss: 0.90, Validation Accuracy: 0.686
# Epoch: 2, Batches per seconds: 54.08, Global step:   1755, Validation Loss: 0.88, Validation Accuracy: 0.695
# Epoch: 2, Batches per seconds: 55.07, Global step:   2106, Validation Loss: 0.86, Validation Accuracy: 0.706
# Epoch: 3, Batches per seconds: 54.46, Global step:   2457, Validation Loss: 0.80, Validation Accuracy: 0.722
# Epoch: 3, Batches per seconds: 55.17, Global step:   2808, Validation Loss: 0.79, Validation Accuracy: 0.725
# Epoch: 4, Batches per seconds: 54.32, Global step:   3159, Validation Loss: 0.83, Validation Accuracy: 0.724
# Epoch: 4, Batches per seconds: 54.86, Global step:   3510, Validation Loss: 0.80, Validation Accuracy: 0.741
# Epoch: 5, Batches per seconds: 54.42, Global step:   3861, Validation Loss: 0.85, Validation Accuracy: 0.731
# Early stop criteria met
# Early stopping.

# %%
create_plots(trainer, "task2")

# %%
train_dl, val_dl, test_dl = dataloaders

# Calculate training and test accuracy
train_acc = 

print(f"{}")
